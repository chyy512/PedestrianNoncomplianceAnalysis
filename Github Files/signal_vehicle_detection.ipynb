# %%
# Signal Detection (Colour detection, Two Phases)

import cv2
import csv
import numpy as np
from collections import deque

# ---------------- Config ----------------
VIDEO_IN = '/Users/cherrychoy/Library/CloudStorage/OneDrive-TheUniversityofSydney(Students)/Honours Thesis/Videos/3 Redfern Street and Pitt Street/RedfernPittPM-Part3.mp4'
VIDEO_OUT = "/Users/cherrychoy/Library/CloudStorage/OneDrive-TheUniversityofSydney(Students)/Honours Thesis/Videos/3 Redfern Street and Pitt Street/PMredfernpitt-Part3_signal_annotated.mp4"

CSV_OUTS = {
    "NS": "/Users/cherrychoy/Library/CloudStorage/OneDrive-TheUniversityofSydney(Students)/Honours Thesis/Videos/3 Redfern Street and Pitt Street/PMP1_signal_logPart3.csv",
    "EW": "/Users/cherrychoy/Library/CloudStorage/OneDrive-TheUniversityofSydney(Students)/Honours Thesis/Videos/3 Redfern Street and Pitt Street/PMP2_signal_logPart3.csv",
}

STABLE_FRAMES = 6       # Number of frames to confirm a state
ROI_FRAME_NUMBER = 7000  # Frame number to select ROI
FRAME_SKIP = 3

# ---------------- Helpers ----------------
def classify_signal_bgr(roi_bgr):
    """Return 'GREEN' or 'NON-GREEN' using robust HSV thresholding"""
    hsv = cv2.cvtColor(roi_bgr, cv2.COLOR_BGR2HSV)
    hsv[..., 2] = cv2.equalizeHist(hsv[..., 2])

    lower_green = np.array([35, 20, 20])
    upper_green = np.array([95, 255, 255])
    green_mask = cv2.inRange(hsv, lower_green, upper_green)

    lower_green_bright = np.array([35, 0, 200])
    upper_green_bright = np.array([95, 30, 255])
    green_mask_bright = cv2.inRange(hsv, lower_green_bright, upper_green_bright)

    green_mask = cv2.bitwise_or(green_mask, green_mask_bright)
    kernel = np.ones((3,3), np.uint8)
    green_mask = cv2.morphologyEx(green_mask, cv2.MORPH_OPEN, kernel)

    green_pixels = int(cv2.countNonZero(green_mask))
    total_pixels = roi_bgr.shape[0] * roi_bgr.shape[1]

    return "GREEN" if green_pixels > total_pixels * 0.1 else "NON-GREEN"

def format_timestamp(seconds):
    """Format seconds into H:MM:SS.mmm"""
    h = int(seconds // 3600)
    m = int((seconds % 3600) // 60)
    s = int(seconds % 60)
    ms = int((seconds - int(seconds)) * 1000)
    return f"{h}:{m:02d}:{s:02d}.{ms:03d}"

# ---------------- Main ----------------
def main():
    cap = cv2.VideoCapture(VIDEO_IN)
    if not cap.isOpened():
        raise RuntimeError(f"Cannot open video: {VIDEO_IN}")

    fps = cap.get(cv2.CAP_PROP_FPS) or 30.0
    w   = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    h   = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

    fourcc = cv2.VideoWriter_fourcc(*"mp4v")
    writer = cv2.VideoWriter(VIDEO_OUT, fourcc, fps, (w, h))

    # --- ROI selection ---
    cap.set(cv2.CAP_PROP_POS_FRAMES, ROI_FRAME_NUMBER)
    ret, frame_for_roi = cap.read()
    if not ret:
        raise RuntimeError(f"Could not read frame {ROI_FRAME_NUMBER} for ROI selection")

    rois = {}
    for key in ["NS", "EW"]:
        print(f"Select ROI for {key}")
        roi = cv2.selectROI(f"Select ROI {key}", frame_for_roi, fromCenter=False, showCrosshair=True)
        cv2.destroyWindow(f"Select ROI {key}")
        x, y, w_roi, h_roi = roi
        rois[key] = (x, y, x + w_roi, y + h_roi)

    # --- Initialize CSV buffers ---
    logs = {key: [] for key in CSV_OUTS.keys()}

    # --- State tracking ---
    states = {}
    for key in rois:
        states[key] = {
            "last": None,
            "count": 0,
            "coords": rois[key],
            "history": deque(maxlen=STABLE_FRAMES)
        }

    frame_idx = 0
    cap.set(cv2.CAP_PROP_POS_FRAMES, 0)

    try:
        while True:
            ret, frame = cap.read()
            if not ret:
                break

            # Skip frames: only process every Nth frame
            if frame_idx % FRAME_SKIP != 0:
                cap.grab()
                frame_idx += 1
                continue

            # ---- Signal detection per ROI ----
            for key in states:
                x1, y1, x2, y2 = states[key]["coords"]
                roi_frame = frame[y1:y2, x1:x2]
                current_state = classify_signal_bgr(roi_frame)

                states[key]["history"].append(current_state)
                majority_state = max(set(states[key]["history"]), key=states[key]["history"].count)

                if majority_state != states[key]["last"]:
                    states[key]["count"] += 1
                    if states[key]["count"] >= STABLE_FRAMES:
                        # Use true video timestamp
                        timestamp_s = cap.get(cv2.CAP_PROP_POS_MSEC) / 1000
                        logs[key].append([timestamp_s, majority_state])
                        states[key]["last"] = majority_state
                        states[key]["count"] = 0
                else:
                    states[key]["count"] = 0

                # Draw ROI and state
                color_map = {"GREEN": (0,255,0), "NON-GREEN": (0,0,255)}
                color = color_map.get(majority_state, (255,255,255))
                cv2.rectangle(frame, (x1,y1), (x2,y2), color, 2)
                cv2.putText(frame, f"{key}: {majority_state}", (x1, y1-10),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.8, color, 2)

            # Timestamp overlay (true video time)
            timestamp_s = cap.get(cv2.CAP_PROP_POS_MSEC) / 1000
            timestamp_text = f"Time: {format_timestamp(timestamp_s)}"
            cv2.putText(frame, timestamp_text, (10, 30),
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255), 2, cv2.LINE_AA)

            writer.write(frame)
            frame_idx += 1

            cv2.imshow("Traffic Signal Logger", frame)
            if cv2.waitKey(10) & 0xFF == ord("q"):
                break

    finally:
        cap.release()
        writer.release()
        cv2.destroyAllWindows()

        # Save CSVs
        for key, path in CSV_OUTS.items():
            with open(path, "w", newline="") as f:
                writer_csv = csv.writer(f)
                writer_csv.writerow(["timestamp_s", "signal_color"])
                writer_csv.writerows(logs[key])

        print(f"Done. CSVs: {', '.join(CSV_OUTS.values())} | Video: {VIDEO_OUT}")

if __name__ == "__main__":
    main()
# Out:
# Select ROI for NS
# Select a ROI and then press SPACE or ENTER button!
# Cancel the selection process by pressing c button!
# Select ROI for EW
# Select a ROI and then press SPACE or ENTER button!
# Cancel the selection process by pressing c button!
# Done. CSVs: /Users/cherrychoy/Library/CloudStorage/OneDrive-TheUniversityofSydney(Students)/Honours Thesis/Videos/3 Redfern Street and Pitt Street/PMP1_signal_logPart3.csv, /Users/cherrychoy/Library/CloudStorage/OneDrive-TheUniversityofSydney(Students)/Honours Thesis/Videos/3 Redfern Street and Pitt Street/PMP2_signal_logPart3.csv | Video: /Users/cherrychoy/Library/CloudStorage/OneDrive-TheUniversityofSydney(Students)/Honours Thesis/Videos/3 Redfern Street and Pitt Street/PMredfernpitt-Part3_signal_annotated.mp4

# %%
# VEH IN CONFLICT ZONES!!

import cv2
import csv
import numpy as np
from ultralytics import YOLO

# CONFIGURATIONS
VIDEO_IN = '/Users/cherrychoy/Library/CloudStorage/OneDrive-TheUniversityofSydney(Students)/Honours Thesis/Videos/3 Redfern Street and Pitt Street/RedfernpittPM-Part4.mp4'
VIDEO_PATH = VIDEO_IN
OUTPUT_VIDEO = "/Users/cherrychoy/Library/CloudStorage/OneDrive-TheUniversityofSydney(Students)/Honours Thesis/Videos/3 Redfern Street and Pitt Street/PMPART4RedfernPitt-vehicle-conflict.mp4"
OUTPUT_CSV = "/Users/cherrychoy/Library/CloudStorage/OneDrive-TheUniversityofSydney(Students)/Honours Thesis/Videos/3 Redfern Street and Pitt Street/PMPART4RedfernPitt-vehicle-conflict.csv"

FRAME_SKIP = 5
FRAME_LINE = 2000
MIN_MOVE_DIST = 10
CONFIDENCE_THRESHOLD = 0.3  

VEHICLE_CLASSES = {
    1: "bicycle",
    2: "car",
    3: "motorcycle",
    5: "bus",
    7: "truck"
}

# INITIALISE YOLO
model = YOLO("yolo11m.pt")

cap = cv2.VideoCapture(VIDEO_PATH)
if not cap.isOpened():
    raise RuntimeError(f"Cannot open video: {VIDEO_PATH}")

frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = cap.get(cv2.CAP_PROP_FPS) or 30.0

out = cv2.VideoWriter(
    OUTPUT_VIDEO,
    cv2.VideoWriter_fourcc(*'mp4v'),
    fps,
    (frame_width, frame_height)
)

# LINE SELECTIONS
LINE_NAMES = ["P1", "P2", "P3", "P4"]
LINE_POINTS = {}

def select_line(event, x, y, flags, param):
    frame_copy, line_name = param
    if event == cv2.EVENT_LBUTTONDOWN:
        if line_name not in LINE_POINTS:
            LINE_POINTS[line_name] = []
        LINE_POINTS[line_name].append((x, y))
        cv2.circle(frame_copy, (x, y), 5, (0, 0, 255), -1)
        cv2.imshow(f"Select {line_name} line", frame_copy)
        if len(LINE_POINTS[line_name]) == 2:
            cv2.destroyWindow(f"Select {line_name} line")

cap.set(cv2.CAP_PROP_POS_FRAMES, FRAME_LINE)
ret, frame_line = cap.read()
if not ret:
    raise RuntimeError(f"Cannot read frame {FRAME_LINE} for line selection")

for name in LINE_NAMES:
    fc = frame_line.copy()
    cv2.imshow(f"Select {name} line", fc)
    cv2.setMouseCallback(f"Select {name} line", select_line, param=(fc, name))
    while name not in LINE_POINTS or len(LINE_POINTS[name]) < 2:
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
cv2.destroyAllWindows()
print("Lines selected:", LINE_POINTS)

# ---------------- HELPERS ----------------
def hms_from_seconds(total_seconds_float: float) -> str:
    total = int(total_seconds_float)
    h = total // 3600
    m = (total % 3600) // 60
    s = total % 60
    return f"{h}:{m:02d}:{s:02d}"

def segments_intersect(p1, p2, q1, q2) -> bool:
    def ccw(a, b, c):
        return (c[1]-a[1]) * (b[0]-a[0]) > (b[1]-a[1]) * (c[0]-a[0])
    return ccw(p1, q1, q2) != ccw(p2, q1, q2) and ccw(p1, p2, q1) != ccw(p1, p2, q2)

def parse_hms(t_str):
    """Convert H:MM:SS string to total seconds."""
    h, m, s = map(int, t_str.split(":"))
    return h*3600 + m*60 + s

# ---------------- PROCESS VIDEO ----------------
vehicle_events = {}
prev_centers = {}
frame_idx = 0

# Phase first-crossing trackers
first_crossing_phase1 = {"P1": None, "P2": None}
first_crossing_phase2 = {"P3": None, "P4": None}
phase1_green_time = None
phase2_green_time = None

cap.set(cv2.CAP_PROP_POS_FRAMES, 0)
try:
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        frame_idx += 1
        if frame_idx % FRAME_SKIP != 0:
            continue

        t_seconds = frame_idx / fps
        t_str = hms_from_seconds(t_seconds)
        cv2.putText(frame, f"Time: {t_str}", (10, 30),
                    cv2.FONT_HERSHEY_SIMPLEX, 1.0, (0, 0, 255), 2)

        for name in LINE_NAMES:
            p1, p2 = LINE_POINTS[name]
            cv2.line(frame, p1, p2, (0, 0, 255), 2)
            cv2.putText(frame, name, p1, cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255, 255, 255), 2)

        # YOLO with ByteTrack
        results = model.track(frame, conf=CONFIDENCE_THRESHOLD, iou=0.3,
                              classes=list(VEHICLE_CLASSES.keys()), persist=True)[0]

        det_boxes_for_class = []
        for box in results.boxes:
            cls = int(box.cls[0])
            if cls not in VEHICLE_CLASSES:
                continue
            x1, y1, x2, y2 = box.xyxy[0].cpu().numpy()
            score = float(box.conf[0])
            if score < CONFIDENCE_THRESHOLD:
                continue
            det_boxes_for_class.append(((x1, y1, x2, y2), cls))

        for box in results.boxes:
            if box.id is None:
                continue

            track_id = int(box.id[0])
            x1, y1, x2, y2 = box.xyxy[0].cpu().numpy()
            cx, cy = int((x1 + x2) / 2), int((y1 + y2) / 2)
            prev_point = prev_centers.get(track_id, (cx, cy))

            dx = cx - prev_point[0]
            dy = cy - prev_point[1]

            # Pick corner based on horizontal movement
            if dx > 0:
                curr_point = (int(x2), int(y2))  # bottom-right
            else:
                curr_point = (int(x1), int(y2))  # bottom-left

            # Store corner point for next frame
            prev_centers[track_id] = curr_point

            if np.hypot(cx - prev_point[0], cy - prev_point[1]) < MIN_MOVE_DIST:
                cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 2)
                cv2.putText(frame, f"ID:{track_id}", (int(x1), max(15, int(y1) - 8)),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
                continue

            cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 2)
            cv2.putText(frame, f"ID:{track_id}", (int(x1), max(15, int(y1) - 8)),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

            # Nearest class
            det_cls = None
            best_d2 = 1e12
            for (bx1, by1, bx2, by2), c_id in det_boxes_for_class:
                dcx, dcy = (bx1 + bx2) / 2.0, (by1 + by2) / 2.0
                d2 = (dcx - cx) ** 2 + (dcy - cy) ** 2
                if d2 < best_d2:
                    best_d2, det_cls = d2, c_id
            veh_type = VEHICLE_CLASSES.get(det_cls, "vehicle")

            # Replace prev_point/curr_point with prev_point and curr_point #CONFIGURE TO INTERSECTION
            for name in LINE_NAMES:
                l1, l2 = LINE_POINTS[name]
                if segments_intersect(prev_point, curr_point, l1, l2):
                    if name in ["P1", "P2"]:
                        if dx > 0: direction = "East"
                        elif dx < 0: direction = "West"
                        else: direction = "Unknown"
                    elif name in ["P3", "P4"]:
                        if dx > 0: direction = "North"
                        elif dx < 0: direction = "South"
                        else: direction = "Unknown"
                    else:
                        direction = "Unknown"

                    if track_id not in vehicle_events:
                        vehicle_events[track_id] = []

                    if not any(e["line"] == name for e in vehicle_events[track_id]):
                        vehicle_events[track_id].append({
                            "time": t_str, "type": veh_type, "line": name, "direction": direction
                        })
                        print(f"[{t_str}] Track {track_id} ({veh_type}) crossed {name} → {direction}")

        out.write(frame)
        cv2.imshow("Tracking", frame)
        if cv2.waitKey(10) & 0xFF == ord('q'):
            print("Quit pressed; saving progress...")
            break

finally:
    cap.release()
    out.release()
    cv2.destroyAllWindows()

    # ---------------- Save vehicle events ----------------
    flat = []
    for tid, entries in vehicle_events.items():
        for e in entries:
            flat.append((tid, e["time"], e["type"], e["line"], e["direction"]))

    flat.sort(key=lambda x: (x[3], x[1]))

    with open(OUTPUT_CSV, "w", newline="") as f:
        w = csv.writer(f)
        w.writerow(["VehicleID", "Time(H:MM:SS)", "Type", "Line", "Direction"])
        w.writerows(flat)

    print(f"Vehicle crossings saved to {OUTPUT_CSV}")
    print(f"Annotated video saved to {OUTPUT_VIDEO}")
# Out:
# Lines selected: {'P1': [(921, 375), (1042, 456)], 'P2': [(309, 407), (557, 373)], 'P3': [(255, 409), (885, 507)], 'P4': [(625, 372), (893, 378)]}
#
# 0: 384x640 5 cars, 363.3ms
# Speed: 2.8ms preprocess, 363.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 359.7ms
# Speed: 3.0ms preprocess, 359.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 362.9ms
# Speed: 1.7ms preprocess, 362.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 372.2ms
# Speed: 1.9ms preprocess, 372.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 351.8ms
# Speed: 1.5ms preprocess, 351.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 350.2ms
# Speed: 1.5ms preprocess, 350.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 358.3ms
# Speed: 1.6ms preprocess, 358.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 358.0ms
# Speed: 1.5ms preprocess, 358.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 363.7ms
# Speed: 1.7ms preprocess, 363.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 354.8ms
# Speed: 1.5ms preprocess, 354.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 350.0ms
# Speed: 1.7ms preprocess, 350.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 363.2ms
# Speed: 1.5ms preprocess, 363.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 356.4ms
# Speed: 2.2ms preprocess, 356.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 451.8ms
# Speed: 1.9ms preprocess, 451.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 354.9ms
# Speed: 1.8ms preprocess, 354.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 355.5ms
# Speed: 2.8ms preprocess, 355.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 358.4ms
# Speed: 1.4ms preprocess, 358.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 365.6ms
# Speed: 1.5ms preprocess, 365.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 355.5ms
# Speed: 1.6ms preprocess, 355.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 348.1ms
# Speed: 1.4ms preprocess, 348.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 356.7ms
# Speed: 1.6ms preprocess, 356.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 353.9ms
# Speed: 1.6ms preprocess, 353.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 354.2ms
# Speed: 1.7ms preprocess, 354.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 351.1ms
# Speed: 1.7ms preprocess, 351.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 352.8ms
# Speed: 1.5ms preprocess, 352.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 363.6ms
# Speed: 1.9ms preprocess, 363.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 369.6ms
# Speed: 1.7ms preprocess, 369.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 353.8ms
# Speed: 1.4ms preprocess, 353.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 356.2ms
# Speed: 1.4ms preprocess, 356.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 355.4ms
# Speed: 1.8ms preprocess, 355.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 356.2ms
# Speed: 1.6ms preprocess, 356.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 359.2ms
# Speed: 1.8ms preprocess, 359.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 348.1ms
# Speed: 2.2ms preprocess, 348.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 372.0ms
# Speed: 1.7ms preprocess, 372.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 354.3ms
# Speed: 2.3ms preprocess, 354.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 356.5ms
# Speed: 1.8ms preprocess, 356.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 345.3ms
# Speed: 2.1ms preprocess, 345.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 341.9ms
# Speed: 1.6ms preprocess, 341.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 346.2ms
# Speed: 1.6ms preprocess, 346.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 398.4ms
# Speed: 1.8ms preprocess, 398.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 353.5ms
# Speed: 1.4ms preprocess, 353.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 341.9ms
# Speed: 1.6ms preprocess, 341.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 342.5ms
# Speed: 1.7ms preprocess, 342.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 345.1ms
# Speed: 1.5ms preprocess, 345.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 349.5ms
# Speed: 1.8ms preprocess, 349.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 343.4ms
# Speed: 1.7ms preprocess, 343.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 353.6ms
# Speed: 1.5ms preprocess, 353.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 346.9ms
# Speed: 1.7ms preprocess, 346.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 347.3ms
# Speed: 1.6ms preprocess, 347.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 358.3ms
# Speed: 1.9ms preprocess, 358.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 348.0ms
# Speed: 2.2ms preprocess, 348.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 345.0ms
# Speed: 2.1ms preprocess, 345.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 349.7ms
# Speed: 1.7ms preprocess, 349.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 356.4ms
# Speed: 1.7ms preprocess, 356.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 357.7ms
# Speed: 1.6ms preprocess, 357.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 346.3ms
# Speed: 1.4ms preprocess, 346.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 343.8ms
# Speed: 1.5ms preprocess, 343.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 389.1ms
# Speed: 1.5ms preprocess, 389.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 348.8ms
# Speed: 1.7ms preprocess, 348.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 345.2ms
# Speed: 2.3ms preprocess, 345.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 347.3ms
# Speed: 1.6ms preprocess, 347.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 343.1ms
# Speed: 1.6ms preprocess, 343.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 351.1ms
# Speed: 1.6ms preprocess, 351.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 360.0ms
# Speed: 1.7ms preprocess, 360.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 346.9ms
# Speed: 1.4ms preprocess, 346.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 349.4ms
# Speed: 1.8ms preprocess, 349.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 350.3ms
# Speed: 1.7ms preprocess, 350.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 343.2ms
# Speed: 1.5ms preprocess, 343.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 359.0ms
# Speed: 1.6ms preprocess, 359.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 349.3ms
# Speed: 1.7ms preprocess, 349.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 349.4ms
# Speed: 1.6ms preprocess, 349.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 347.5ms
# Speed: 1.4ms preprocess, 347.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 353.5ms
# Speed: 1.7ms preprocess, 353.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 352.1ms
# Speed: 2.1ms preprocess, 352.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 354.7ms
# Speed: 1.5ms preprocess, 354.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 364.8ms
# Speed: 1.5ms preprocess, 364.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 352.2ms
# Speed: 1.5ms preprocess, 352.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 361.6ms
# Speed: 1.7ms preprocess, 361.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 354.0ms
# Speed: 1.6ms preprocess, 354.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 351.5ms
# Speed: 1.5ms preprocess, 351.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 349.2ms
# Speed: 1.5ms preprocess, 349.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 357.5ms
# Speed: 1.6ms preprocess, 357.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 363.0ms
# Speed: 1.6ms preprocess, 363.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 352.3ms
# Speed: 1.5ms preprocess, 352.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 345.8ms
# Speed: 1.5ms preprocess, 345.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 351.0ms
# Speed: 1.6ms preprocess, 351.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 361.1ms
# Speed: 1.5ms preprocess, 361.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 357.4ms
# Speed: 1.7ms preprocess, 357.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 352.0ms
# Speed: 1.7ms preprocess, 352.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 358.5ms
# Speed: 1.4ms preprocess, 358.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# [0:00:07] Track 19 (car) crossed P2 → East
#
# 0: 384x640 6 cars, 355.4ms
# Speed: 1.6ms preprocess, 355.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 363.8ms
# Speed: 1.9ms preprocess, 363.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 349.2ms
# Speed: 1.5ms preprocess, 349.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 367.4ms
# Speed: 1.5ms preprocess, 367.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 346.9ms
# Speed: 1.4ms preprocess, 346.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 352.9ms
# Speed: 1.4ms preprocess, 352.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 354.3ms
# Speed: 1.7ms preprocess, 354.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 352.8ms
# Speed: 1.5ms preprocess, 352.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 353.6ms
# Speed: 1.7ms preprocess, 353.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 356.0ms
# Speed: 1.6ms preprocess, 356.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 361.4ms
# Speed: 1.6ms preprocess, 361.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 350.2ms
# Speed: 1.7ms preprocess, 350.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 346.7ms
# Speed: 1.6ms preprocess, 346.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 349.6ms
# Speed: 2.1ms preprocess, 349.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 356.1ms
# Speed: 1.8ms preprocess, 356.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 374.7ms
# Speed: 1.7ms preprocess, 374.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 351.0ms
# Speed: 1.4ms preprocess, 351.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 357.3ms
# Speed: 1.5ms preprocess, 357.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 349.0ms
# Speed: 1.6ms preprocess, 349.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 352.0ms
# Speed: 1.5ms preprocess, 352.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 355.0ms
# Speed: 1.7ms preprocess, 355.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 361.0ms
# Speed: 1.9ms preprocess, 361.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 385.5ms
# Speed: 1.8ms preprocess, 385.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 399.6ms
# Speed: 1.4ms preprocess, 399.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 397.2ms
# Speed: 1.5ms preprocess, 397.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 409.8ms
# Speed: 2.0ms preprocess, 409.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 427.1ms
# Speed: 5.3ms preprocess, 427.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 356.6ms
# Speed: 1.5ms preprocess, 356.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 348.4ms
# Speed: 1.5ms preprocess, 348.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 358.0ms
# Speed: 1.6ms preprocess, 358.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 348.9ms
# Speed: 1.4ms preprocess, 348.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 352.0ms
# Speed: 1.7ms preprocess, 352.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 350.9ms
# Speed: 1.5ms preprocess, 350.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 351.3ms
# Speed: 1.5ms preprocess, 351.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 346.9ms
# Speed: 1.5ms preprocess, 346.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 354.1ms
# Speed: 1.5ms preprocess, 354.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 376.7ms
# Speed: 1.6ms preprocess, 376.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 385.9ms
# Speed: 1.9ms preprocess, 385.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 378.5ms
# Speed: 1.8ms preprocess, 378.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 382.6ms
# Speed: 1.5ms preprocess, 382.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 349.0ms
# Speed: 1.9ms preprocess, 349.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 406.1ms
# Speed: 1.5ms preprocess, 406.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 407.7ms
# Speed: 2.8ms preprocess, 407.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 396.7ms
# Speed: 2.6ms preprocess, 396.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 363.9ms
# Speed: 1.6ms preprocess, 363.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 378.7ms
# Speed: 1.6ms preprocess, 378.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 348.7ms
# Speed: 1.3ms preprocess, 348.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 343.3ms
# Speed: 1.5ms preprocess, 343.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 344.9ms
# Speed: 1.7ms preprocess, 344.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 369.4ms
# Speed: 1.9ms preprocess, 369.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 349.1ms
# Speed: 4.9ms preprocess, 349.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 346.9ms
# Speed: 1.5ms preprocess, 346.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 351.0ms
# Speed: 1.5ms preprocess, 351.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 344.8ms
# Speed: 1.5ms preprocess, 344.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 345.5ms
# Speed: 1.5ms preprocess, 345.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 366.1ms
# Speed: 1.5ms preprocess, 366.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 367.8ms
# Speed: 2.8ms preprocess, 367.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 366.9ms
# Speed: 3.5ms preprocess, 366.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 391.1ms
# Speed: 1.5ms preprocess, 391.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 428.0ms
# Speed: 1.4ms preprocess, 428.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 363.1ms
# Speed: 1.6ms preprocess, 363.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 353.8ms
# Speed: 1.4ms preprocess, 353.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 343.0ms
# Speed: 1.3ms preprocess, 343.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 356.1ms
# Speed: 1.5ms preprocess, 356.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 346.1ms
# Speed: 1.3ms preprocess, 346.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 340.1ms
# Speed: 1.4ms preprocess, 340.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 342.0ms
# Speed: 1.5ms preprocess, 342.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 346.2ms
# Speed: 2.2ms preprocess, 346.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 345.9ms
# Speed: 1.7ms preprocess, 345.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 377.3ms
# Speed: 1.6ms preprocess, 377.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 344.7ms
# Speed: 1.4ms preprocess, 344.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 341.0ms
# Speed: 1.8ms preprocess, 341.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 344.6ms
# Speed: 1.7ms preprocess, 344.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 344.7ms
# Speed: 1.5ms preprocess, 344.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 342.9ms
# Speed: 2.0ms preprocess, 342.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 363.8ms
# Speed: 1.5ms preprocess, 363.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 342.3ms
# Speed: 1.6ms preprocess, 342.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 343.8ms
# Speed: 1.6ms preprocess, 343.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 345.5ms
# Speed: 1.6ms preprocess, 345.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 338.6ms
# Speed: 1.6ms preprocess, 338.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 345.6ms
# Speed: 1.5ms preprocess, 345.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 347.1ms
# Speed: 1.5ms preprocess, 347.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 346.6ms
# Speed: 1.6ms preprocess, 346.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 341.3ms
# Speed: 1.5ms preprocess, 341.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 344.5ms
# Speed: 2.2ms preprocess, 344.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 339.0ms
# Speed: 1.6ms preprocess, 339.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 345.7ms
# Speed: 1.5ms preprocess, 345.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 368.1ms
# Speed: 3.1ms preprocess, 368.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 405.5ms
# Speed: 2.9ms preprocess, 405.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 382.0ms
# Speed: 4.0ms preprocess, 382.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 358.5ms
# Speed: 1.5ms preprocess, 358.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 339.1ms
# Speed: 1.6ms preprocess, 339.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 338.6ms
# Speed: 1.5ms preprocess, 338.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 352.8ms
# Speed: 1.6ms preprocess, 352.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 405.6ms
# Speed: 1.9ms preprocess, 405.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 345.1ms
# Speed: 1.4ms preprocess, 345.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 342.6ms
# Speed: 2.2ms preprocess, 342.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 342.0ms
# Speed: 1.5ms preprocess, 342.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 338.9ms
# Speed: 1.7ms preprocess, 338.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 340.5ms
# Speed: 1.6ms preprocess, 340.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 341.3ms
# Speed: 1.4ms preprocess, 341.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 340.9ms
# Speed: 1.7ms preprocess, 340.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 380.5ms
# Speed: 1.8ms preprocess, 380.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 356.9ms
# Speed: 1.5ms preprocess, 356.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 364.1ms
# Speed: 1.6ms preprocess, 364.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 387.2ms
# Speed: 1.7ms preprocess, 387.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 337.2ms
# Speed: 1.7ms preprocess, 337.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 338.0ms
# Speed: 1.5ms preprocess, 338.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 339.5ms
# Speed: 1.5ms preprocess, 339.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 337.3ms
# Speed: 1.4ms preprocess, 337.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 345.1ms
# Speed: 1.7ms preprocess, 345.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 339.3ms
# Speed: 1.5ms preprocess, 339.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 350.6ms
# Speed: 1.4ms preprocess, 350.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 332.3ms
# Speed: 1.5ms preprocess, 332.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 343.3ms
# Speed: 1.7ms preprocess, 343.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 342.9ms
# Speed: 1.3ms preprocess, 342.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 337.6ms
# Speed: 1.4ms preprocess, 337.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 339.6ms
# Speed: 1.6ms preprocess, 339.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 336.7ms
# Speed: 1.5ms preprocess, 336.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 344.1ms
# Speed: 1.5ms preprocess, 344.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 340.7ms
# Speed: 1.6ms preprocess, 340.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 337.9ms
# Speed: 1.6ms preprocess, 337.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 342.6ms
# Speed: 1.5ms preprocess, 342.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 339.0ms
# Speed: 1.5ms preprocess, 339.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 345.1ms
# Speed: 2.0ms preprocess, 345.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 345.9ms
# Speed: 1.5ms preprocess, 345.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 353.6ms
# Speed: 1.4ms preprocess, 353.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 337.1ms
# Speed: 1.5ms preprocess, 337.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 337.1ms
# Speed: 1.6ms preprocess, 337.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 343.8ms
# Speed: 1.4ms preprocess, 343.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 334.6ms
# Speed: 1.3ms preprocess, 334.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 341.2ms
# Speed: 1.4ms preprocess, 341.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 337.2ms
# Speed: 1.4ms preprocess, 337.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 334.5ms
# Speed: 1.5ms preprocess, 334.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 340.1ms
# Speed: 1.8ms preprocess, 340.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 336.8ms
# Speed: 1.4ms preprocess, 336.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 351.9ms
# Speed: 1.2ms preprocess, 351.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 336.5ms
# Speed: 1.6ms preprocess, 336.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 341.4ms
# Speed: 1.6ms preprocess, 341.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 342.5ms
# Speed: 1.5ms preprocess, 342.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 339.7ms
# Speed: 1.5ms preprocess, 339.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 339.3ms
# Speed: 1.5ms preprocess, 339.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 341.0ms
# Speed: 1.5ms preprocess, 341.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 338.2ms
# Speed: 1.9ms preprocess, 338.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 1 truck, 335.1ms
# Speed: 1.5ms preprocess, 335.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 336.8ms
# Speed: 1.6ms preprocess, 336.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 336.9ms
# Speed: 1.5ms preprocess, 336.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 334.7ms
# Speed: 1.4ms preprocess, 334.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 348.9ms
# Speed: 1.7ms preprocess, 348.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# [0:00:19] Track 19 (car) crossed P4 → North
#
# 0: 384x640 4 cars, 336.7ms
# Speed: 1.4ms preprocess, 336.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 341.2ms
# Speed: 1.5ms preprocess, 341.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 340.2ms
# Speed: 1.9ms preprocess, 340.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 337.8ms
# Speed: 1.5ms preprocess, 337.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 348.7ms
# Speed: 1.5ms preprocess, 348.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 333.6ms
# Speed: 1.7ms preprocess, 333.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 344.0ms
# Speed: 1.5ms preprocess, 344.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 348.8ms
# Speed: 1.4ms preprocess, 348.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 345.4ms
# Speed: 1.6ms preprocess, 345.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 395.9ms
# Speed: 1.6ms preprocess, 395.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 414.4ms
# Speed: 2.2ms preprocess, 414.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 465.7ms
# Speed: 2.4ms preprocess, 465.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 398.1ms
# Speed: 1.6ms preprocess, 398.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 456.4ms
# Speed: 1.6ms preprocess, 456.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 403.6ms
# Speed: 2.2ms preprocess, 403.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 362.1ms
# Speed: 2.2ms preprocess, 362.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 359.6ms
# Speed: 1.8ms preprocess, 359.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 362.9ms
# Speed: 1.6ms preprocess, 362.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 356.5ms
# Speed: 1.7ms preprocess, 356.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 403.1ms
# Speed: 2.4ms preprocess, 403.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 466.2ms
# Speed: 2.7ms preprocess, 466.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 417.7ms
# Speed: 1.8ms preprocess, 417.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 362.9ms
# Speed: 3.3ms preprocess, 362.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 351.6ms
# Speed: 2.0ms preprocess, 351.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 357.2ms
# Speed: 1.4ms preprocess, 357.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 354.8ms
# Speed: 1.5ms preprocess, 354.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 347.2ms
# Speed: 2.0ms preprocess, 347.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 346.5ms
# Speed: 1.5ms preprocess, 346.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 343.4ms
# Speed: 2.2ms preprocess, 343.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 357.6ms
# Speed: 1.5ms preprocess, 357.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 369.2ms
# Speed: 2.3ms preprocess, 369.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 359.6ms
# Speed: 1.8ms preprocess, 359.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 387.9ms
# Speed: 1.7ms preprocess, 387.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 377.0ms
# Speed: 1.8ms preprocess, 377.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 366.1ms
# Speed: 1.7ms preprocess, 366.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 409.6ms
# Speed: 1.9ms preprocess, 409.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 410.7ms
# Speed: 1.3ms preprocess, 410.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 378.3ms
# Speed: 1.6ms preprocess, 378.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 393.6ms
# Speed: 1.5ms preprocess, 393.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 363.0ms
# Speed: 1.5ms preprocess, 363.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 353.2ms
# Speed: 2.2ms preprocess, 353.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 356.0ms
# Speed: 1.5ms preprocess, 356.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 365.9ms
# Speed: 1.9ms preprocess, 365.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 359.1ms
# Speed: 1.4ms preprocess, 359.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 347.8ms
# Speed: 1.9ms preprocess, 347.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 349.8ms
# Speed: 1.5ms preprocess, 349.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 342.7ms
# Speed: 1.7ms preprocess, 342.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 343.9ms
# Speed: 1.3ms preprocess, 343.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 363.5ms
# Speed: 2.1ms preprocess, 363.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 365.6ms
# Speed: 1.5ms preprocess, 365.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 369.0ms
# Speed: 1.7ms preprocess, 369.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 360.7ms
# Speed: 1.7ms preprocess, 360.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 354.6ms
# Speed: 1.6ms preprocess, 354.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 391.5ms
# Speed: 1.5ms preprocess, 391.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 386.6ms
# Speed: 1.6ms preprocess, 386.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 387.1ms
# Speed: 2.4ms preprocess, 387.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 457.8ms
# Speed: 1.9ms preprocess, 457.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 408.3ms
# Speed: 1.5ms preprocess, 408.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 398.9ms
# Speed: 1.8ms preprocess, 398.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 377.9ms
# Speed: 1.4ms preprocess, 377.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 440.4ms
# Speed: 2.2ms preprocess, 440.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 466.4ms
# Speed: 2.1ms preprocess, 466.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 367.7ms
# Speed: 2.0ms preprocess, 367.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 459.5ms
# Speed: 1.9ms preprocess, 459.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 606.9ms
# Speed: 4.7ms preprocess, 606.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 543.7ms
# Speed: 2.1ms preprocess, 543.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 481.2ms
# Speed: 2.1ms preprocess, 481.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 457.1ms
# Speed: 3.6ms preprocess, 457.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 453.8ms
# Speed: 2.0ms preprocess, 453.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 428.2ms
# Speed: 1.5ms preprocess, 428.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 483.5ms
# Speed: 2.0ms preprocess, 483.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 462.6ms
# Speed: 1.8ms preprocess, 462.6ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 853.5ms
# Speed: 2.7ms preprocess, 853.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 631.2ms
# Speed: 2.8ms preprocess, 631.2ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 474.9ms
# Speed: 4.8ms preprocess, 474.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 455.4ms
# Speed: 2.0ms preprocess, 455.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 397.9ms
# Speed: 4.2ms preprocess, 397.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 378.8ms
# Speed: 1.5ms preprocess, 378.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 392.4ms
# Speed: 2.0ms preprocess, 392.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 362.5ms
# Speed: 1.4ms preprocess, 362.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 386.0ms
# Speed: 4.7ms preprocess, 386.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 362.2ms
# Speed: 1.7ms preprocess, 362.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 394.9ms
# Speed: 1.8ms preprocess, 394.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 370.5ms
# Speed: 4.9ms preprocess, 370.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 387.3ms
# Speed: 2.4ms preprocess, 387.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 408.9ms
# Speed: 1.6ms preprocess, 408.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 376.0ms
# Speed: 3.5ms preprocess, 376.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 357.2ms
# Speed: 1.6ms preprocess, 357.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 455.1ms
# Speed: 1.9ms preprocess, 455.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 815.9ms
# Speed: 3.7ms preprocess, 815.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 389.3ms
# Speed: 1.7ms preprocess, 389.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 395.7ms
# Speed: 1.7ms preprocess, 395.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 556.6ms
# Speed: 1.7ms preprocess, 556.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 356.9ms
# Speed: 1.4ms preprocess, 356.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 352.0ms
# Speed: 1.5ms preprocess, 352.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 365.5ms
# Speed: 5.9ms preprocess, 365.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 398.1ms
# Speed: 2.1ms preprocess, 398.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 361.8ms
# Speed: 1.7ms preprocess, 361.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 342.9ms
# Speed: 1.5ms preprocess, 342.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 347.0ms
# Speed: 1.5ms preprocess, 347.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 356.9ms
# Speed: 2.5ms preprocess, 356.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 345.1ms
# Speed: 1.5ms preprocess, 345.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 347.5ms
# Speed: 2.4ms preprocess, 347.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 350.4ms
# Speed: 1.5ms preprocess, 350.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 348.8ms
# Speed: 2.0ms preprocess, 348.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 439.6ms
# Speed: 1.7ms preprocess, 439.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 415.4ms
# Speed: 2.8ms preprocess, 415.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 371.3ms
# Speed: 5.4ms preprocess, 371.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 343.9ms
# Speed: 2.7ms preprocess, 343.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 344.9ms
# Speed: 1.5ms preprocess, 344.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 341.7ms
# Speed: 1.5ms preprocess, 341.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 347.5ms
# Speed: 1.5ms preprocess, 347.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 486.9ms
# Speed: 1.5ms preprocess, 486.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 369.6ms
# Speed: 1.4ms preprocess, 369.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 361.8ms
# Speed: 1.5ms preprocess, 361.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 358.2ms
# Speed: 1.5ms preprocess, 358.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 431.8ms
# Speed: 1.9ms preprocess, 431.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 404.5ms
# Speed: 1.8ms preprocess, 404.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 404.7ms
# Speed: 1.5ms preprocess, 404.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 416.1ms
# Speed: 1.9ms preprocess, 416.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 445.2ms
# Speed: 2.1ms preprocess, 445.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 446.7ms
# Speed: 1.6ms preprocess, 446.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 438.8ms
# Speed: 1.7ms preprocess, 438.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 432.0ms
# Speed: 2.4ms preprocess, 432.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 454.8ms
# Speed: 2.1ms preprocess, 454.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 444.0ms
# Speed: 1.6ms preprocess, 444.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 420.9ms
# Speed: 2.4ms preprocess, 420.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 430.0ms
# Speed: 3.7ms preprocess, 430.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 397.0ms
# Speed: 1.5ms preprocess, 397.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 677.8ms
# Speed: 1.8ms preprocess, 677.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 606.8ms
# Speed: 1.8ms preprocess, 606.8ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 561.8ms
# Speed: 4.2ms preprocess, 561.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 474.8ms
# Speed: 16.8ms preprocess, 474.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 457.1ms
# Speed: 1.8ms preprocess, 457.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 389.6ms
# Speed: 1.7ms preprocess, 389.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 372.1ms
# Speed: 1.5ms preprocess, 372.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 434.3ms
# Speed: 4.5ms preprocess, 434.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 388.2ms
# Speed: 1.6ms preprocess, 388.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 388.3ms
# ...
# [0:11:30] Track 1637 (truck) crossed P3 → North
#
# 0: 384x640 2 cars, 2 trucks, 363.0ms
# Speed: 1.7ms preprocess, 363.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 346.1ms
# Speed: 2.0ms preprocess, 346.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 351.7ms
# Speed: 1.6ms preprocess, 351.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# [0:11:31] Track 1630 (car) crossed P4 → North
#
# 0: 384x640 2 cars, 2 trucks, 346.0ms
# Speed: 1.6ms preprocess, 346.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 344.9ms
# Speed: 1.6ms preprocess, 344.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 350.4ms
# Speed: 1.5ms preprocess, 350.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 352.1ms
# Speed: 1.6ms preprocess, 352.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 1 truck, 365.3ms
# Speed: 1.6ms preprocess, 365.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 367.1ms
# Speed: 1.6ms preprocess, 367.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 1 truck, 407.7ms
# Speed: 1.5ms preprocess, 407.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 1 truck, 403.6ms
# Speed: 1.9ms preprocess, 403.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 1 truck, 378.9ms
# Speed: 2.2ms preprocess, 378.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 truck, 359.9ms
# Speed: 1.9ms preprocess, 359.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 truck, 439.6ms
# Speed: 1.8ms preprocess, 439.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 truck, 409.7ms
# Speed: 1.6ms preprocess, 409.7ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 buss, 1 truck, 389.0ms
# Speed: 1.5ms preprocess, 389.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 buss, 1 truck, 423.3ms
# Speed: 1.8ms preprocess, 423.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 366.5ms
# Speed: 2.2ms preprocess, 366.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 truck, 372.6ms
# Speed: 3.5ms preprocess, 372.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 truck, 416.1ms
# Speed: 3.1ms preprocess, 416.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 truck, 358.1ms
# Speed: 2.1ms preprocess, 358.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 trucks, 358.1ms
# Speed: 1.5ms preprocess, 358.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 351.5ms
# Speed: 2.0ms preprocess, 351.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 438.4ms
# Speed: 2.4ms preprocess, 438.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 1 truck, 385.7ms
# Speed: 1.9ms preprocess, 385.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# [0:11:32] Track 1637 (bus) crossed P2 → West
#
# 0: 384x640 6 cars, 1 truck, 390.8ms
# Speed: 1.5ms preprocess, 390.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 460.8ms
# Speed: 6.5ms preprocess, 460.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 430.9ms
# Speed: 2.4ms preprocess, 430.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 434.9ms
# Speed: 2.0ms preprocess, 434.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 449.4ms
# Speed: 1.8ms preprocess, 449.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# [0:11:33] Track 1693 (car) crossed P3 → North
#
# 0: 384x640 7 cars, 2 trucks, 468.3ms
# Speed: 4.6ms preprocess, 468.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 trucks, 494.8ms
# Speed: 1.6ms preprocess, 494.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# [0:11:33] Track 1706 (car) crossed P2 → East
#
# 0: 384x640 6 cars, 1 truck, 476.4ms
# Speed: 3.5ms preprocess, 476.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 464.9ms
# Speed: 2.8ms preprocess, 464.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 444.5ms
# Speed: 1.5ms preprocess, 444.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 1 truck, 472.5ms
# Speed: 2.1ms preprocess, 472.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 2 trucks, 442.7ms
# Speed: 2.8ms preprocess, 442.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 truck, 410.5ms
# Speed: 1.9ms preprocess, 410.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 2 trucks, 392.7ms
# Speed: 1.6ms preprocess, 392.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 buss, 1 truck, 421.7ms
# Speed: 1.6ms preprocess, 421.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 trucks, 449.2ms
# Speed: 2.2ms preprocess, 449.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# [0:11:34] Track 1682 (truck) crossed P4 → South
#
# 0: 384x640 8 cars, 1 truck, 504.0ms
# Speed: 3.5ms preprocess, 504.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 trucks, 384.5ms
# Speed: 2.0ms preprocess, 384.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 386.4ms
# Speed: 1.5ms preprocess, 386.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 437.3ms
# Speed: 4.2ms preprocess, 437.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 375.0ms
# Speed: 2.0ms preprocess, 375.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 427.5ms
# Speed: 2.5ms preprocess, 427.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 379.4ms
# Speed: 1.9ms preprocess, 379.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 359.9ms
# Speed: 1.4ms preprocess, 359.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 1 truck, 397.1ms
# Speed: 2.2ms preprocess, 397.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 truck, 490.7ms
# Speed: 4.1ms preprocess, 490.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [0:11:35] Track 1712 (bus) crossed P4 → North
#
# 0: 384x640 6 cars, 1 bus, 1 truck, 493.6ms
# Speed: 2.5ms preprocess, 493.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 452.4ms
# Speed: 2.1ms preprocess, 452.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 446.3ms
# Speed: 2.4ms preprocess, 446.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 444.8ms
# Speed: 2.1ms preprocess, 444.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 568.8ms
# Speed: 2.3ms preprocess, 568.8ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 435.0ms
# Speed: 1.6ms preprocess, 435.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 445.3ms
# Speed: 3.0ms preprocess, 445.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 451.7ms
# Speed: 2.3ms preprocess, 451.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 445.3ms
# Speed: 2.5ms preprocess, 445.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 464.5ms
# Speed: 1.5ms preprocess, 464.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 487.0ms
# Speed: 2.1ms preprocess, 487.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 trucks, 500.1ms
# Speed: 2.1ms preprocess, 500.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 595.6ms
# Speed: 1.8ms preprocess, 595.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [0:11:36] Track 1693 (car) crossed P4 → North
#
# 0: 384x640 7 cars, 2 trucks, 433.3ms
# Speed: 2.8ms preprocess, 433.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 359.7ms
# Speed: 2.3ms preprocess, 359.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 419.1ms
# Speed: 1.7ms preprocess, 419.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 372.0ms
# Speed: 1.7ms preprocess, 372.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 402.5ms
# Speed: 1.7ms preprocess, 402.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 410.4ms
# Speed: 2.3ms preprocess, 410.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 511.4ms
# Speed: 2.4ms preprocess, 511.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 483.3ms
# Speed: 1.8ms preprocess, 483.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# [0:11:36] Track 1723 (car) crossed P3 → North
#
# 0: 384x640 6 cars, 1 truck, 482.4ms
# Speed: 2.4ms preprocess, 482.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 558.0ms
# Speed: 2.4ms preprocess, 558.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 481.1ms
# Speed: 1.8ms preprocess, 481.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 487.2ms
# Speed: 3.1ms preprocess, 487.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 459.2ms
# Speed: 1.7ms preprocess, 459.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 520.7ms
# Speed: 1.9ms preprocess, 520.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 505.7ms
# Speed: 2.3ms preprocess, 505.7ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 437.8ms
# Speed: 2.1ms preprocess, 437.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 522.0ms
# Speed: 2.0ms preprocess, 522.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 360.2ms
# Speed: 2.2ms preprocess, 360.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 370.6ms
# Speed: 1.5ms preprocess, 370.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 truck, 371.5ms
# Speed: 1.5ms preprocess, 371.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 truck, 364.1ms
# Speed: 1.9ms preprocess, 364.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 truck, 372.2ms
# Speed: 1.6ms preprocess, 372.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 1 truck, 435.9ms
# Speed: 2.2ms preprocess, 435.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 truck, 367.5ms
# Speed: 2.5ms preprocess, 367.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 458.4ms
# Speed: 2.1ms preprocess, 458.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 370.6ms
# Speed: 1.6ms preprocess, 370.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 368.8ms
# Speed: 1.8ms preprocess, 368.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 365.4ms
# Speed: 1.5ms preprocess, 365.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 364.4ms
# Speed: 1.5ms preprocess, 364.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 367.2ms
# Speed: 1.6ms preprocess, 367.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# [0:11:38] Track 1723 (car) crossed P4 → North
#
# 0: 384x640 7 cars, 1 truck, 354.9ms
# Speed: 2.1ms preprocess, 354.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 366.9ms
# Speed: 2.1ms preprocess, 366.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 446.5ms
# Speed: 1.5ms preprocess, 446.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 372.8ms
# Speed: 2.0ms preprocess, 372.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 362.6ms
# Speed: 1.7ms preprocess, 362.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 481.8ms
# Speed: 2.3ms preprocess, 481.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 392.8ms
# Speed: 1.7ms preprocess, 392.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 373.0ms
# Speed: 2.1ms preprocess, 373.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 357.1ms
# Speed: 2.2ms preprocess, 357.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 357.7ms
# Speed: 1.8ms preprocess, 357.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 355.9ms
# Speed: 1.5ms preprocess, 355.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 355.1ms
# Speed: 2.3ms preprocess, 355.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 1 truck, 379.7ms
# Speed: 2.0ms preprocess, 379.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 380.6ms
# Speed: 3.7ms preprocess, 380.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 366.2ms
# Speed: 1.7ms preprocess, 366.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 364.3ms
# Speed: 1.7ms preprocess, 364.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle crossings saved to /Users/cherrychoy/Library/CloudStorage/OneDrive-TheUniversityofSydney(Students)/Honours Thesis/Videos/3 Redfern Street and Pitt Street/PMPART4RedfernPitt-vehicle-conflict.csv
# Annotated video saved to /Users/cherrychoy/Library/CloudStorage/OneDrive-TheUniversityofSydney(Students)/Honours Thesis/Videos/3 Redfern Street and Pitt Street/PMPART4RedfernPitt-vehicle-conflict.mp4
